# %%
# ==================================================
# CELL 1: Import All Necessary Libraries
# ==================================================

# Data manipulation libraries
import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Utility libraries
import warnings
import os

# Ignore warning messages to keep output clean
warnings.filterwarnings('ignore')

# Make plots appear in the notebook
# %matplotlib inline

# Set plot style for beautiful visualizations
sns.set_style("whitegrid")
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (14, 7)
plt.rcParams['font.size'] = 11

# Display all columns in pandas (don't truncate)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

print("="*60)
print("✅ ALL LIBRARIES IMPORTED SUCCESSFULLY!")
print("="*60)
print("📊 Pandas version:", pd.__version__)
print("🔢 NumPy version:", np.__version__)
print("="*60)
print("🎯 READY TO LOAD YOUR DATASET!")
print("="*60)
# Out:
# ============================================================
# ✅ ALL LIBRARIES IMPORTED SUCCESSFULLY!
# ============================================================
# 📊 Pandas version: 2.3.3
# 🔢 NumPy version: 1.26.4
# ============================================================
# 🎯 READY TO LOAD YOUR DATASET!
# ============================================================

# %%
data_path = '../data/raw/complaints.csv'

print("🔄 Loading dataset... This might take 30-60 seconds...")
print("📂 Loading from:", data_path)
print("-" * 60)

# Load the CSV file
df = pd.read_csv(data_path, low_memory=False)

print("✅ DATASET LOADED SUCCESSFULLY!")
print("="*60)
print(f"📊 Total Rows (Records): {df.shape[0]:,}")
print(f"📋 Total Columns (Features): {df.shape[1]}")
print("="*60)
print("💾 Dataset Size in Memory:", round(df.memory_usage(deep=True).sum() / 1024**2, 2), "MB")
print("="*60)
# Out:
# 🔄 Loading dataset... This might take 30-60 seconds...
# 📂 Loading from: ../data/raw/complaints.csv
# ------------------------------------------------------------
# ✅ DATASET LOADED SUCCESSFULLY!
# ============================================================
# 📊 Total Rows (Records): 777,959
# 📋 Total Columns (Features): 18
# ============================================================
# 💾 Dataset Size in Memory: 868.67 MB
# ============================================================

# %%
# ==================================================
# CELL 3: Display First 5 Rows of Data
# ==================================================

print("👀 FIRST 5 ROWS OF YOUR DATASET:")
print("="*60)
df.head()
# Out:
# 👀 FIRST 5 ROWS OF YOUR DATASET:
# ============================================================
#   Date received           Product                            Sub-product  \
# 0    03/21/2017  Credit reporting                                    NaN
# 1    04/19/2017   Debt collection  Other (i.e. phone, health club, etc.)
# 2    04/19/2017       Credit card                                    NaN
# 3    04/14/2017          Mortgage                         Other mortgage
# 4    04/19/2017       Credit card                                    NaN
#
#                                       Issue  \
# 0    Incorrect information on credit report
# 1           Disclosure verification of debt
# 2                                     Other
# 3  Loan modification,collection,foreclosure
# 4                      Credit determination
#
#                                 Sub-issue Consumer complaint narrative  \
# 0                 Information is not mine                          NaN
# 1  Not disclosed as an attempt to collect                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#                                                                            Company public response  \
# 0  Company has responded to the consumer and the CFPB and chooses not to provide a public response
# 1                                                                                              NaN
# 2  Company has responded to the consumer and the CFPB and chooses not to provide a public response
# 3                         Company believes it acted appropriately as authorized by contract or law
# 4  Company has responded to the consumer and the CFPB and chooses not to provide a public response
#
#                          Company State ZIP code            Tags  \
# 0           EXPERIAN DELAWARE GP    TX    77075  Older American
# 1  Security Credit Services, LLC    IL    60643             NaN
# 2                 CITIBANK, N.A.    IL    62025             NaN
# 3       Shellpoint Partners, LLC    CA    90305             NaN
# 4                   U.S. BANCORP    LA    70571             NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN         Phone           03/21/2017
# 1                        NaN           Web           04/20/2017
# 2                        NaN      Referral           04/20/2017
# 3                        NaN      Referral           04/14/2017
# 4                        NaN   Postal mail           04/21/2017
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0  Closed with non-monetary relief              Yes                 No
# 1          Closed with explanation              Yes                 No
# 2          Closed with explanation              Yes                 No
# 3          Closed with explanation              Yes                 No
# 4          Closed with explanation              Yes                 No
#
#    Complaint ID
# 0       2397100
# 1       2441777
# 2       2441830
# 3       2436165
# 4       2441726

# %%
# ==================================================
# CELL 4: Examine All Columns and Their Data Types
# ==================================================

print("📋 COLUMN INFORMATION:")
print("="*60)
print(f"Total Columns: {len(df.columns)}")
print("="*60)
print("\n📝 Column Names and Data Types:\n")
df.info()
# Out:
# 📋 COLUMN INFORMATION:
# ============================================================
# Total Columns: 18
# ============================================================
#
# 📝 Column Names and Data Types:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777959 entries, 0 to 777958
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date received                 777959 non-null  object
#  1   Product                       777959 non-null  object
#  2   Sub-product                   542822 non-null  object
#  3   Issue                         777959 non-null  object
#  4   Sub-issue                     320986 non-null  object
#  5   Consumer complaint narrative  157865 non-null  object
#  6   Company public response       197884 non-null  object
#  7   Company                       777959 non-null  object
#  8   State                         772056 non-null  object
#  9   ZIP code                      772001 non-null  object
#  10  Tags                          109264 non-null  object
#  11  Consumer consent provided?    288311 non-null  object
#  12  Submitted via                 777959 non-null  object
#  13  Date sent to company          777959 non-null  object
#  14  Company response to consumer  777959 non-null  object
#  15  Timely response?              777959 non-null  object
#  16  Consumer disputed?            768414 non-null  object
#  17  Complaint ID                  777959 non-null  int64
# dtypes: int64(1), object(17)
# memory usage: 106.8+ MB

# %%
# ==================================================
# CELL 5: Analyze Missing Values
# ==================================================

print("🔍 MISSING VALUES ANALYSIS:")
print("="*60)

# Calculate missing values
missing_values = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

# Create a summary dataframe
missing_df = pd.DataFrame({
    'Column': missing_values.index,
    'Missing_Count': missing_values.values,
    'Missing_Percent': missing_percent.values
})

# Filter to show only columns with missing values
missing_df = missing_df[missing_df['Missing_Count'] > 0].sort_values('Missing_Percent', ascending=False)

if len(missing_df) > 0:
    print(f"⚠️  Found {len(missing_df)} columns with missing values:\n")
    print(missing_df.to_string(index=False))
else:
    print("✅ No missing values found in any column!")

print("\n" + "="*60)
# Out:
# 🔍 MISSING VALUES ANALYSIS:
# ============================================================
# ⚠️  Found 9 columns with missing values:
#
#                       Column  Missing_Count  Missing_Percent
#                         Tags         668695        85.955044
# Consumer complaint narrative         620094        79.707800
#      Company public response         580075        74.563698
#   Consumer consent provided?         489648        62.940078
#                    Sub-issue         456973        58.739985
#                  Sub-product         235137        30.224858
#           Consumer disputed?           9545         1.226928
#                     ZIP code           5958         0.765850
#                        State           5903         0.758780
#
# ============================================================

# %%
# ==================================================
# CELL 6: Statistical Summary of Numerical Data
# ==================================================

print("📊 STATISTICAL SUMMARY OF NUMERICAL COLUMNS:")
print("="*60)
df.describe()
# Out:
# 📊 STATISTICAL SUMMARY OF NUMERICAL COLUMNS:
# ============================================================
#        Complaint ID
# count  7.779590e+05
# mean   1.310413e+06
# std    7.287276e+05
# min    1.000000e+00
# 25%    6.912890e+05
# 50%    1.353374e+06
# 75%    1.956984e+06
# max    2.488370e+06

# %%
# ==================================================
# CELL 7: Explore Important Columns for Dispute Model
# ==================================================

# Let's look at all column names first
print("📝 ALL AVAILABLE COLUMNS IN YOUR DATASET:")
print("="*60)
for idx, col in enumerate(df.columns, 1):
    print(f"{idx}. {col}")
print("="*60)

# Check which columns might be useful for dispute resolution
print("\n🎯 LOOKING FOR KEY COLUMNS...")
print("="*60)

# Common important columns for dispute resolution
important_keywords = ['complaint', 'narrative', 'issue', 'product', 
                     'company', 'response', 'resolution', 'consumer', 
                     'timely', 'disputed']

print("\n🔍 Columns that might contain dispute information:\n")
for col in df.columns:
    col_lower = col.lower()
    if any(keyword in col_lower for keyword in important_keywords):
        print(f"✓ {col}")

print("\n" + "="*60)
# Out:
# 📝 ALL AVAILABLE COLUMNS IN YOUR DATASET:
# ============================================================
# 1. Date received
# 2. Product
# 3. Sub-product
# 4. Issue
# 5. Sub-issue
# 6. Consumer complaint narrative
# 7. Company public response
# 8. Company
# 9. State
# 10. ZIP code
# 11. Tags
# 12. Consumer consent provided?
# 13. Submitted via
# 14. Date sent to company
# 15. Company response to consumer
# 16. Timely response?
# 17. Consumer disputed?
# 18. Complaint ID
# ============================================================
#
# 🎯 LOOKING FOR KEY COLUMNS...
# ============================================================
#
# 🔍 Columns that might contain dispute information:
#
# ✓ Product
# ✓ Sub-product
# ✓ Issue
# ✓ Sub-issue
# ✓ Consumer complaint narrative
# ✓ Company public response
# ✓ Company
# ✓ Consumer consent provided?
# ✓ Date sent to company
# ✓ Company response to consumer
# ✓ Timely response?
# ✓ Consumer disputed?
# ✓ Complaint ID
#
# ============================================================

# %%
# ==================================================
# CELL 8: Find and Analyze the Resolution/Response Column
# ==================================================

# Try to find the response/resolution column
# It might be called different things in your dataset
possible_response_cols = []

for col in df.columns:
    col_lower = col.lower()
    if 'response' in col_lower or 'resolution' in col_lower or 'company' in col_lower:
        possible_response_cols.append(col)

print("🎯 POSSIBLE RESPONSE/RESOLUTION COLUMNS:")
print("="*60)
for col in possible_response_cols:
    print(f"\n📌 Column: {col}")
    print("-"*60)
    print(f"Unique values count: {df[col].nunique()}")
    print(f"\nUnique values:")
    print(df[col].value_counts())
    print("="*60)
# Out:
# 🎯 POSSIBLE RESPONSE/RESOLUTION COLUMNS:
# ============================================================
#
# 📌 Column: Company public response
# ------------------------------------------------------------
# Unique values count: 10
#
# Unique values:
# Company public response
# Company has responded to the consumer and the CFPB and chooses not to provide a public response                            97492
# Company chooses not to provide a public response                                                                           52473
# Company believes it acted appropriately as authorized by contract or law                                                   34323
# Company believes the complaint is the result of a misunderstanding                                                          3149
# Company disputes the facts presented in the complaint                                                                       2887
# Company believes complaint caused principally by actions of third party outside the control or direction of the company     2579
# Company believes complaint is the result of an isolated error                                                               2323
# Company can't verify or dispute the facts in the complaint                                                                  1549
# Company believes complaint represents an opportunity for improvement to better serve consumers                              1067
# Company believes complaint relates to a discontinued policy or procedure                                                      42
# Name: count, dtype: int64
# ============================================================
#
# 📌 Column: Company
# ------------------------------------------------------------
# Unique values count: 4224
#
# Unique values:
# Company
# BANK OF AMERICA, NATIONAL ASSOCIATION         66314
# WELLS FARGO BANK, NATIONAL ASSOCIATION        54090
# EQUIFAX, INC.                                 49162
# EXPERIAN DELAWARE GP                          46896
# JPMORGAN CHASE & CO.                          42997
#                                               ...
# SUCCESS MORTGAGE PARTNERS, INC                    1
# House of Finance Corp.                            1
# NJ Automotive Accounts Management Co, Inc.        1
# Peters & Associates, LLP                          1
# Krawczyk, Duginski & Rohr, S.C.                   1
# Name: count, Length: 4224, dtype: int64
# ============================================================
#
# 📌 Column: Date sent to company
# ------------------------------------------------------------
# Unique values count: 1944
#
# Unique values:
# Date sent to company
# 01/19/2017    1614
# 01/20/2017    1467
# 01/24/2017    1236
# 01/25/2017    1149
# 02/07/2017    1112
#               ...
# 01/16/2012       1
# 02/19/2012       1
# 02/23/2013       1
# 03/18/2012       1
# 12/18/2011       1
# Name: count, Length: 1944, dtype: int64
# ============================================================
#
# 📌 Column: Company response to consumer
# ------------------------------------------------------------
# Unique values count: 8
#
# Unique values:
# Company response to consumer
# Closed with explanation            581562
# Closed with non-monetary relief     95957
# Closed with monetary relief         51581
# Closed without relief               17868
# Closed                              17611
# Closed with relief                   5304
# In progress                          4382
# Untimely response                    3694
# Name: count, dtype: int64
# ============================================================
#
# 📌 Column: Timely response?
# ------------------------------------------------------------
# Unique values count: 2
#
# Unique values:
# Timely response?
# Yes    756162
# No      21797
# Name: count, dtype: int64
# ============================================================

# %%
# ==================================================
# CELL 9: Explore Complaint Text/Narrative Column
# ==================================================

# Find narrative/text columns
narrative_cols = []

for col in df.columns:
    col_lower = col.lower()
    if 'narrative' in col_lower or 'description' in col_lower or 'complaint' in col_lower:
        # Check if it's a text column with actual narratives
        if df[col].dtype == 'object':
            narrative_cols.append(col)

print("📝 NARRATIVE/TEXT COLUMNS FOUND:")
print("="*60)

for col in narrative_cols:
    print(f"\n📌 Column: {col}")
    print("-"*60)
    print(f"Total entries: {df[col].count():,}")
    print(f"Missing entries: {df[col].isnull().sum():,}")
    print(f"Non-null percentage: {(df[col].count() / len(df)) * 100:.2f}%")
    
    # Show a sample narrative
    sample_narratives = df[col].dropna().head(3)
    if len(sample_narratives) > 0:
        print(f"\n📖 Sample narratives from '{col}':")
        print("-"*60)
        for idx, narrative in enumerate(sample_narratives, 1):
            print(f"\nExample {idx}:")
            print(narrative[:300] + "..." if len(str(narrative)) > 300 else narrative)
            print("-"*40)
    
    print("="*60)
# Out:
# 📝 NARRATIVE/TEXT COLUMNS FOUND:
# ============================================================
#
# 📌 Column: Consumer complaint narrative
# ------------------------------------------------------------
# Total entries: 157,865
# Missing entries: 620,094
# Non-null percentage: 20.29%
#
# 📖 Sample narratives from 'Consumer complaint narrative':
# ------------------------------------------------------------
#
# Example 1:
# Started the refinance of home mortgage process with cash out option on XX/XX/2016. Necessary documents were submitted by XXXX. After initial review, got good faith estimate with loan amount and closing cost. Based on this estimate, a deposit of {$350.00} was made towards appraisal. Appraisal came wi...
# ----------------------------------------
#
# Example 2:
# My wife and I visited the Chase Bank branch at XXXX, XXXX, KY on XX/XX/2017 around XXXX AM to open new checking accounts. We were prompted to open these checking accounts because Chase mailed and emailed us vouchers to receive {$300.00} for opening each account and personal friends had also referred...
# ----------------------------------------
#
# Example 3:
# The service representative was harsh and not listening to my questions. Attempting to collect on a debt I thought was in a grace period because I had just finished school in XXXX and it is only XXXX. Why would know one contact me prior to this? I let her know I could n't afford the XXXX a month and ...
# ----------------------------------------
# ============================================================

# %%
# ==================================================
# CELL 10: Final Summary - What We Have for Our Model
# ==================================================

print("="*70)
print(" 🎯 DATASET SUMMARY FOR ESCROW DISPUTE RESOLUTION MODEL")
print("="*70)

print(f"\n📊 DATASET SIZE:")
print(f"   • Total complaints (rows): {len(df):,}")
print(f"   • Total features (columns): {df.shape[1]}")
print(f"   • Memory usage: {round(df.memory_usage(deep=True).sum() / 1024**2, 2)} MB")

print(f"\n📝 DATA COMPLETENESS:")
total_cells = df.shape[0] * df.shape[1]
total_missing = df.isnull().sum().sum()
print(f"   • Total data cells: {total_cells:,}")
print(f"   • Missing cells: {total_missing:,}")
print(f"   • Completeness: {((total_cells - total_missing) / total_cells * 100):.2f}%")

print(f"\n🎯 NEXT STEPS FOR BUILDING DISPUTE MODEL:")
print("   1. ✓ Data loaded successfully")
print("   2. ⏭️  Create target labels (favour_customer, favor_seller, split_payment)")
print("   3. ⏭️  Clean and preprocess text data")
print("   4. ⏭️  Feature engineering from complaint narratives")
print("   5. ⏭️  Build machine learning model")
print("   6. ⏭️  Evaluate model performance")
print("   7. ⏭️  Create prediction system")

print("\n" + "="*70)
print("🎉 DATA EXPLORATION COMPLETE!")
print("="*70)
print("\n💡 TIP: Look at the columns carefully above.")
print("   We need to identify which column shows dispute outcomes!")
print("="*70)
# Out:
# ======================================================================
#  🎯 DATASET SUMMARY FOR ESCROW DISPUTE RESOLUTION MODEL
# ======================================================================
#
# 📊 DATASET SIZE:
#    • Total complaints (rows): 777,959
#    • Total features (columns): 18
#    • Memory usage: 868.68 MB
#
# 📝 DATA COMPLETENESS:
#    • Total data cells: 14,003,262
#    • Missing cells: 3,072,028
#    • Completeness: 78.06%
#
# 🎯 NEXT STEPS FOR BUILDING DISPUTE MODEL:
#    1. ✓ Data loaded successfully
#    2. ⏭️  Create target labels (favour_customer, favor_seller, split_payment)
#    3. ⏭️  Clean and preprocess text data
#    4. ⏭️  Feature engineering from complaint narratives
#    5. ⏭️  Build machine learning model
#    6. ⏭️  Evaluate model performance
#    7. ⏭️  Create prediction system
#
# ======================================================================
# 🎉 DATA EXPLORATION COMPLETE!
# ======================================================================
#
# 💡 TIP: Look at the columns carefully above.
#    We need to identify which column shows dispute outcomes!
# ======================================================================
